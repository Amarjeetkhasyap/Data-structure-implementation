# %%
class Node:
    def __init__(self,data=None):
        
        self.data=data
        self.leftchild=None
        self.rightchild=None
class bst:
    def __init__(self):
        self.root=None
    def insert(self,data):
        if self.root==None:
            
            self.root = Node(data)
        else:
            self.insertnode(data,self.root)
    def insertnode(self,data,node):
        if data < node.data:
            if node.leftchild: #means if there is alredy a left child
                self.insertnode (data,node.leftchild)
            else:
                node.leftchild = Node(data)
        else:
            if node.rightchild: #if right child is already available
                self.insertnode(data,node.rightchild)
            else:
                node.rightchild = Node(data)
    def print_tree(self):
        if self.root!=None:
            self._print_tree(self.root)
    
    

    def _print_tree(self,node):
        if node!=None:
            self._print_tree(node.leftchild)
            print(str(node.data))
            self._print_tree(node.rightchild)
    def minvalue(self):
        if self.root:
            return self._getmin(self.root)
    def _getmin(self,node):
        if node.leftchild:
            return self._getmin(node.leftchild)
        return node.data
    def maxvalue(self):
        if self.root:
            return self._getmax(self.root)
    def _getmax(self,node):
        if node.rightchild:
            return self._getmax(node.rightchild)
        return node.data
my = bst()
my.insert(32)
my.insert(10)
my.insert(55)
my.insert(0)
my.insert(19)
my.insert(79)
my.insert(16)
my.insert(23)
